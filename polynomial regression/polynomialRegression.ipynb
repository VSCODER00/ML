# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = 6 * np.random.rand(100, 1) - 3

# %%
y=0.5 * x**2 + 1.5*x + 2 + np.random.randn(100, 1)

# %%
y.shape
# Out:
# (100, 1)

# %%
y
# Out:
# array([[ 8.25148627],
#        [ 2.25987492],
#        [ 7.11238338],
#        [ 6.0018969 ],
#        [ 1.09006398],
#        [ 2.8190526 ],
#        [ 0.68015157],
#        [ 1.5214112 ],
#        [ 6.54742897],
#        [12.09185458],
#        [ 2.06395744],
#        [ 1.4662815 ],
#        [ 1.22160221],
#        [ 0.8291068 ],
#        [ 5.52638337],
#        [ 6.54071668],
#        [ 0.15844142],
#        [ 1.55280563],
#        [ 3.5021849 ],
#        [ 8.63524975],
#        [ 2.11886232],
#        [ 0.71724562],
#        [ 5.80523093],
#        [ 5.27616373],
#        [ 6.65418397],
#        [ 1.52641628],
#        [ 4.89320005],
#        [ 4.07834822],
#        [ 0.91286174],
#        [ 8.44413362],
#        [ 8.32250949],
#        [ 2.63539321],
#        [ 2.59743363],
#        [-0.74320599],
#        [-2.09937289],
#        [ 5.17816099],
#        [ 4.02499212],
#        [-0.37240721],
#        [ 9.77620761],
#        [ 5.36757261],
#        [ 1.5920059 ],
# ...

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.5662356237281492

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,y_pred,color='r')

# %%
plt.plot(x_train,model.predict(x_train),color='r')
plt.scatter(x,y)
plt.xlabel("X Dataset")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
# as observed, r2 score when linear regression is used is too low, hence we use polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
x_train_poly=poly.fit_transform(x_train)
x_test_poly=poly.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_pred_poly=regression.predict(x_test_poly)

# %%
from sklearn.metrics import r2_score
newScore=r2_score(y_test,y_pred_poly)
print(newScore)
# Out:
# 0.8427313214621486

# %%
#here , we sort as (x_test,y_pred_poly) and then we plot the best fit line
# Get sorting indices
sorted_indices = np.argsort(x_test.ravel())  

# Sort both x_test and y_pred_poly together
x_test_sorted = x_test[sorted_indices]       
y_pred_poly_sorted = y_pred_poly[sorted_indices]  

# Plot scatter for training data
plt.scatter(x_train, y_train, label="Training Data", color="blue")

# Plot sorted polynomial regression line
plt.plot(x_test_sorted, y_pred_poly_sorted, color='red', label="Polynomial Regression Fit")

# %%
# Out:
# numpy.ndarray
